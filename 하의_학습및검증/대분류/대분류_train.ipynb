# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, models
from torch.utils.data import DataLoader, Dataset
from PIL import Image

# %%
dataframe = pd.read_csv("D:/minkwan/졸업작품/coordikitty-ML-DL/dataframe_real_last.csv")
# dataframe.to_csv("dataframe_real_last.csv", index=False, encoding='utf-8')
dataframe
# Out:
#                                  image_file  \
# 0      BOTTOMS_LONG_COTTON_image_1005_0.jpg
# 1      BOTTOMS_LONG_COTTON_image_1010_1.jpg
# 2      BOTTOMS_LONG_COTTON_image_1012_3.jpg
# 3      BOTTOMS_LONG_COTTON_image_1014_1.jpg
# 4      BOTTOMS_LONG_COTTON_image_1016_1.jpg
# ...                                     ...
# 15546   TOPS_SHORT_T_SHIRTS_image_997_1.jpg
# 15547   TOPS_SHORT_T_SHIRTS_image_998_6.jpg
# 15548   TOPS_SHORT_T_SHIRTS_image_999_4.jpg
# 15549    TOPS_SHORT_T_SHIRTS_image_99_1.jpg
# 15550     TOPS_SHORT_T_SHIRTS_image_9_0.jpg
#
#                                 label_file large_category medium_category  \
# 0      1005_label_BOTTOMS_LONG_COTTON.json        BOTTOMS            LONG
# 1      1010_label_BOTTOMS_LONG_COTTON.json        BOTTOMS            LONG
# 2      1012_label_BOTTOMS_LONG_COTTON.json        BOTTOMS            LONG
# 3      1014_label_BOTTOMS_LONG_COTTON.json        BOTTOMS            LONG
# 4      1016_label_BOTTOMS_LONG_COTTON.json        BOTTOMS            LONG
# ...                                    ...            ...             ...
# 15546   997_label_TOPS_SHORT_T_SHIRTS.json           TOPS           SHORT
# 15547   998_label_TOPS_SHORT_T_SHIRTS.json           TOPS           SHORT
# 15548   999_label_TOPS_SHORT_T_SHIRTS.json           TOPS           SHORT
# 15549    99_label_TOPS_SHORT_T_SHIRTS.json           TOPS           SHORT
# 15550     9_label_TOPS_SHORT_T_SHIRTS.json           TOPS           SHORT
#
#       small_category                핏       촉감    신축성     비침   두께  \
# 0             COTTON               루즈   약간 뻣뻣함     없음     없음  NaN
# 1             COTTON              레귤러       보통     보통     보통   보통
# 2             COTTON               루즈       보통     없음     없음   보통
# 3             COTTON              레귤러       보통  약간 있음     없음   보통
# 4             COTTON               루즈       보통     없음     없음   보통
# ...              ...              ...      ...    ...    ...  ...
# 15546       T_SHIRTS           오버 사이즈     부드러움     있음     없음   보통
# 15547       T_SHIRTS           오버 사이즈       보통     보통  거의 없음   보통
# 15548       T_SHIRTS              레귤러     부드러움     있음     없음   보통
# 15549       T_SHIRTS               루즈       보통     보통  거의 없음   보통
# 15550       T_SHIRTS  레귤러, 루즈, 오버 사이즈  약간 부드러움  약간 있음     없음   보통
#
#                   계절 major_style minor_style
# 0              봄, 가을         미니멀         캐주얼
# 1          봄, 여름, 가을         미니멀         캐주얼
# 2                 여름         미니멀         캐주얼
# 3          봄, 여름, 가을         미니멀         캐주얼
# 4      봄, 여름, 가을, 겨울         미니멀         캐주얼
# ...              ...         ...         ...
# 15546  봄, 여름, 가을, 겨울         캐주얼         스트릿
# 15547      봄, 여름, 가을         캐주얼         스트릿
# 15548  봄, 여름, 가을, 겨울         캐주얼         스트릿
# 15549          봄, 여름         캐주얼         스트릿
# 15550      봄, 여름, 가을         캐주얼         스트릿
#
# [15551 rows x 13 columns]

# %%
# 라벨 인코딩을 위한 사전 생성
label_mapping = {label: idx for idx, label in enumerate(dataframe['large_category'].unique())}
dataframe['label'] = dataframe['large_category'].map(label_mapping)  # 새로운 숫자형 라벨 컬럼 추가

# %%
# 라벨 매핑 출력
print("라벨 매핑:")
for label, idx in label_mapping.items():
    print(f"'{label}': {idx}")
# Out:
# 라벨 매핑:
# 'BOTTOMS': 0
# 'TOPS': 1

# %%
# CustomDataset 클래스 정의
class CustomDataset(Dataset):
    def __init__(self, dataframe, image_dir, label_column, transform=None):
        self.dataframe = dataframe
        self.image_dir = image_dir
        self.label_column = label_column
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        # 이미지 파일 이름을 데이터프레임의 'image_file' 컬럼에서 가져옴
        img_name = os.path.join(self.image_dir, self.dataframe.iloc[idx]['image_file'])
        
        # 이미지 열기
        image = Image.open(img_name).convert('RGB')
        label = self.dataframe.iloc[idx]['label']  # 숫자형 라벨 사용

        if self.transform:
            image = self.transform(image)

        # 라벨을 Tensor로 변환
        label = torch.tensor(label, dtype=torch.long)

        return image, label  # (image, label) 튜플 반환

# %%
image_dir = "D:\minkwan\졸업작품\coordikitty-ML-DL\image_root_dir"
label_column = 'large_category'  # 사용할 라벨 컬럼

# %%
# 이미지 전처리 변환
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
# 데이터셋 및 데이터로더 초기화
dataset = CustomDataset(dataframe, image_dir, label_column, transform)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
# ResNeXt 모델 정의
model = models.resnext50_32x4d(pretrained=True)  # ResNeXt50 모델
num_classes = len(dataframe[label_column].unique())
model.fc = nn.Linear(model.fc.in_features, num_classes)
# Out:
# c:\Users\User\anaconda3\envs\Pytorch_CK\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\User\anaconda3\envs\Pytorch_CK\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 모델을 GPU 또는 CPU로 이동
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
criterion = nn.CrossEntropyLoss()  # 다중 클래스 분류
optimizer = optim.Adam(model.parameters(), lr=0.001)
print(device)
# Out:
# cuda

# %%
# 학습 루프
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    for batch in dataloader:
        images, labels = batch  # 배치를 언팩킹
        images, labels = images.to(device), labels.to(device)  # 이미지와 라벨을 device로 이동

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

print("학습 완료!")
# Out:
# Epoch [1/10], Loss: 0.0006
# Epoch [2/10], Loss: 0.0074
# Epoch [3/10], Loss: 0.0618
# Epoch [4/10], Loss: 0.0001
# Epoch [5/10], Loss: 0.0000
# Epoch [6/10], Loss: 0.0007
# Epoch [7/10], Loss: 0.0001
# Epoch [8/10], Loss: 0.0006
# Epoch [9/10], Loss: 0.0002
# Epoch [10/10], Loss: 0.0001
# 학습 완료!

# %%
# 학습된 모델 가중치 저장
model_save_path = 'resnext_model_large.pth'  # 저장할 파일 경로
torch.save(model.state_dict(), model_save_path)

print("학습 완료 및 모델 가중치 저장!")
# Out:
# 학습 완료 및 모델 가중치 저장!
